# %%
import pandas as pd
import os

# %%
LiteDaily = os.path.join('Resources/LitecoinDaily.csv')
LiteD_df = pd.read_csv(LiteDaily)
LiteD_df
# Out:
#           Date    Price     Open     High      Low     Vol. Change %
# 0     2-Mar-23   94.940   97.850   98.270   93.920  526.85K   -2.97%
# 1     1-Mar-23   97.850   93.790   98.190   93.640  578.27K    4.33%
# 2    28-Feb-23   93.790   94.070   95.990   93.100  380.29K   -0.30%
# 3    27-Feb-23   94.070   95.270   96.070   92.600  390.66K   -1.26%
# 4    26-Feb-23   95.270   93.160   95.520   92.790  343.66K    2.26%
# ..         ...      ...      ...      ...      ...      ...      ...
# 786   5-Jan-21  158.432  155.461  162.548  146.542  383.44M    1.87%
# 787   4-Jan-21  155.518  161.310  173.625  140.003  519.23M   -3.50%
# 788   3-Jan-21  161.151  136.932  164.398  135.401  394.35M   17.82%
# 789   2-Jan-21  136.781  126.232  140.646  123.153  283.31M    8.30%
# 790   1-Jan-21  126.302  124.162  133.919  122.943  257.82M    1.72%
#
# [791 rows x 7 columns]

# %%
LiteD_df['Date'] = pd.to_datetime(LiteD_df['Date'])
LiteD_df['Day'] = LiteD_df['Date'].dt.day_name()
LiteD_df
# Out:
#           Date    Price     Open     High      Low     Vol. Change %  \
# 0   2023-03-02   94.940   97.850   98.270   93.920  526.85K   -2.97%
# 1   2023-03-01   97.850   93.790   98.190   93.640  578.27K    4.33%
# 2   2023-02-28   93.790   94.070   95.990   93.100  380.29K   -0.30%
# 3   2023-02-27   94.070   95.270   96.070   92.600  390.66K   -1.26%
# 4   2023-02-26   95.270   93.160   95.520   92.790  343.66K    2.26%
# ..         ...      ...      ...      ...      ...      ...      ...
# 786 2021-01-05  158.432  155.461  162.548  146.542  383.44M    1.87%
# 787 2021-01-04  155.518  161.310  173.625  140.003  519.23M   -3.50%
# 788 2021-01-03  161.151  136.932  164.398  135.401  394.35M   17.82%
# 789 2021-01-02  136.781  126.232  140.646  123.153  283.31M    8.30%
# 790 2021-01-01  126.302  124.162  133.919  122.943  257.82M    1.72%
#
#            Day
# 0     Thursday
# 1    Wednesday
# 2      Tuesday
# 3       Monday
# 4       Sunday
# ..         ...
# 786    Tuesday
# ...

# %%
LiteD_df.dtypes
# Out:
# Date        datetime64[ns]
# Price              float64
# Open               float64
# High               float64
# Low                float64
# Vol.                object
# Change %            object
# Day                 object
# dtype: object

# %%
for column in LiteD_df.columns:
    print(f"Column {column} has {LiteD_df[column].isnull().sum()}null values")
# Out:
# Column Date has 0null values
# Column Price has 0null values
# Column Open has 0null values
# Column High has 0null values
# Column Low has 0null values
# Column Vol. has 0null values
# Column Change % has 0null values
# Column Day has 0null values

# %%
# Remove customer ID column
LiteD_df.drop(columns=["Open", "High", "Low", "Vol.", "Change %", "Date"], inplace=True)
LiteD_df.head()
# Out:
#    Price        Day
# 0  94.94   Thursday
# 1  97.85  Wednesday
# 2  93.79    Tuesday
# 3  94.07     Monday
# 4  95.27     Sunday

# %%
LiteDay_df = LiteD_df.groupby(by='Day').mean()
LiteDay_df
# Out:
#                 Price
# Day
# Friday     129.504283
# Monday     129.210168
# Saturday   129.700398
# Sunday     129.830673
# Thursday   129.272053
# Tuesday    129.641274
# Wednesday  129.853664

# %%
# Saving cleaned data
file_path = "Resources/LiteDay.csv"
LiteD_df.to_csv(file_path, index=False)

# %%
import matplotlib.pyplot as plt

# %%
LiteD_df.plot ("Day","Price")
x = ('Day')
y= ('Price')
plt.title("LiteCoin Avg by Day of the Week")
plt.show()
